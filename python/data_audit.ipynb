# %% [markdown]
# Phase-1

# %%
import pandas as pd

df = pd.read_excel("../data/raw/amazon_sales.xlsx")

print("Shape:", df.shape)
print("\nColumns:\n", df.columns.tolist())
print("\nDtypes:\n", df.dtypes)
print("\nSample row:\n", df.iloc[0])
print("\nNull counts:\n", df.isnull().sum())
# Out:
# Shape: (1465, 16)
#
# Columns:
#  ['product_id', 'product_name', 'category', 'discounted_price', 'actual_price', 'discount_percentage', 'rating', 'rating_count', 'about_product', 'user_id', 'user_name', 'review_id', 'review_title', 'review_content', 'img_link', 'product_link']
#
# Dtypes:
#  product_id                 str
# product_name               str
# category                   str
# discounted_price           str
# actual_price               str
# discount_percentage    float64
# rating                     str
# rating_count           float64
# about_product              str
# user_id                    str
# user_name                  str
# review_id                  str
# review_title               str
# review_content             str
# img_link                   str
# product_link               str
# dtype: object
#
# Sample row:
#  product_id                                                    B07JW9H4J1
# ...

# %%
df[['user_id', 'user_name', 'review_title']].iloc[[0]]
# Out:
#                                              user_id  \
# 0  AG3D6O4STAQKAY2UVGEUV46KN35Q,AHMY5CWJMMK5BJRBB...
#
#                                            user_name  \
# 0  Manav,Adarsh gupta,Sundeep,S.Sayeed Ahmed,jasp...
#
#                                         review_title
# 0  Satisfied,Charging is really fast,Value for mo...

# %%
df['n_reviewers'] = df['user_id'].astype(str).str.split(',').apply(len)
print(df['n_reviewers'].describe())
# Out:
# count    1465.000000
# mean        7.851877
# std         0.827654
# min         1.000000
# 25%         8.000000
# 50%         8.000000
# 75%         8.000000
# max         8.000000
# Name: n_reviewers, dtype: float64

# %%
print(df[['actual_price','discounted_price','discount_percentage','rating','rating_count']].describe())
# Out:
#        discount_percentage   rating_count
# count          1465.000000    1463.000000
# mean              0.476915   18295.541353
# std               0.216359   42753.864952
# min               0.000000       2.000000
# 25%               0.320000    1186.000000
# 50%               0.500000    5179.000000
# 75%               0.630000   17336.500000
# max               0.940000  426973.000000

# %%
# Unpack the review grain

df.to_csv("../data/processed/products_clean.csv", index=False)

# %%
# Print the exact count of hidden non-numeric placeholder rows
print("Mismatched or missing rating values:", pd.to_numeric(df['rating'], errors='coerce').isnull().sum())
# Out:
# Mismatched or missing rating values: 1

# %%
df = df[df['rating'] != '|'].copy()
df['rating'] = df['rating'].astype(float)
print("Rows after dropping bad rating:", df.shape[0])
# Out:
# Rows after dropping bad rating: 1464

# %%
df.to_csv("../data/processed/products_clean.csv", index=False)
print("Saved updated file to products_clean.csv")
# Out:
# Saved updated file to products_clean.csv
